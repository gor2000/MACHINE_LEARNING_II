# %% [markdown]
# **Imagine that, after computing a grid search for a particular ML problem, you obtain the following results:**

# %% [markdown]
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# **Which model do you consider to be the best one to put into production? Why?**

# %% [markdown]
# - Model 1: Clear Overfitting, not a good choice.
#
# - Model 2: Model with the highest AUC_val. However, the difference with respect to AUC_train is significant, it looks like it may suffer from overfitting.
#
# - Model 3: Performance almost equal to the maximum AUC_val achieved. AUC_val and AUC_train really similar, does not look like it suffers from overfitting.
#
# - Model 4: Poor AUC_val compared with model 2 and model 3. Looks like an underfitting problem, as it AUC_train is way lower than the one in the other models.

# %% [markdown]
# Based on this, I will probably select **model 3** as my best model to put into production.
