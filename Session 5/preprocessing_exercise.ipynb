# %%
# Load libraries
import numpy as np;
import pandas as pd;

# %% [markdown]
# # **Preprocessing Exercise**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63de334a-aca1-45b0-9a90-ae7f1fa270b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63de334a-aca1-45b0-9a90-ae7f1fa270b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
dat = pd.read_csv(io.BytesIO(uploaded['healthcare_missing.csv']), sep = ",")
dat
# Out:
#           date  severity  mortality_ratio      age  num_proc  ambulatory  \
# 0      2016-01       NaN         0.408730  12596.0      21.0         0.0
# 1      2016-01       NaN         0.306931  20973.0      22.0         NaN
# 2      2016-01       4.0         0.278481  19611.0      19.0         NaN
# 3      2016-01       3.0         0.150289  13583.0      22.0         NaN
# 4      2016-01       1.0         0.016573  18042.0       2.0         NaN
# ...        ...       ...              ...      ...       ...         ...
# 32701  2016-12       2.0         0.028365  23619.0       2.0         NaN
# 32702  2016-12       1.0         0.000606   3935.0       1.0         NaN
# 32703  2016-12       NaN         0.040452  30163.0       4.0         NaN
# 32704  2016-12       NaN         0.000000  29012.0       4.0         NaN
# 32705  2016-12       NaN         0.000000  13244.0       1.0         NaN
#
#        origin  expected_length tip_grd  tip_adm  exitus
# ...

# %%
dat.describe()
# Out:
#            severity  mortality_ratio           age      num_proc   ambulatory  \
# count  12072.000000     30438.000000  32282.000000  31356.000000  1959.000000
# mean       1.618125         0.030209  19241.077164      4.080973     0.069934
# std        0.928901         0.066488   9314.930503      2.826585     0.255100
# min        1.000000         0.000000      0.000000      0.000000     0.000000
# 25%        1.000000         0.000000  12349.250000      2.000000     0.000000
# 50%        1.000000         0.001095  19916.500000      4.000000     0.000000
# 75%        2.000000         0.028365  26940.750000      5.000000     0.000000
# max        4.000000         0.666667  38292.000000     22.000000     1.000000
#
#              origin  expected_length       tip_adm        exitus
# count  12246.000000     30833.000000  26617.000000  32706.000000
# mean       1.520088         4.986540      1.271931      0.038403
# std        1.345335         7.488703      0.475574      0.192169
# ...

# %% [markdown]
# Try to implement some of the preprocessing steps we have covered. The complete list is:
#
# ![imagen.png](data:image/png;base64,...)

# %% [markdown]
# Some examples could be:
#
# - Oversampling of the minority class (exitus = 1).
# - Remove not informed variables (e.g., >50% NAs).
# - Fill missing values using MICE.
# - One Hot Encoding of the categorical variables.
# - Scaling to mean = 0 and std = 1.
# - Remove irrelevant (e.g., |correlation| < 0.05).
# - Feature selection using variable importance based on permutation_importance (e.g., top 80%).
