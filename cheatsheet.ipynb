# %%
                        #Regression:
                        # [5] Predict
                        pred_train = model.predict(X_train) # predict!
                        pred_val = model.predict(X_val) # predict!

                        # [6] Compute metric
                        metric_train = metric(y_train, pred_train)
                        metric_val = metric(y_val, pred_val)

                        # Binary classification - F1 Score/accuracy/sensititvity:
                        # [5] Predict
                        pred_train = model.predict(X_train) # predict!
                        pred_val = model.predict(X_val) # predict!

                        # [6] Compute metric
                        metric_train = metric(y_train, pred_train)
                        metric_val = metric(y_val, pred_val)

                        # Binary classification - AUC:
                        # [5] Predict
                        pred_train = model.predict_proba(X_train) # predict!
                        pred_val = model.predict_proba(X_val) # predict!

                        # [6] Compute metric
                        metric_train = metric(y_train, pred_train[:,1])
                        metric_val = metric(y_val, pred_val[:,1])

                          # Multiclassification - F1 Score/accuracy/sensititvity:
                        # [5] Predict
                        pred_train = model.predict(X_train) # predict!
                        pred_val = model.predict(X_val) # predict!

                        # [6] Compute metric
                        metric_train = metric(y_train, pred_train, multi_class = 'ovr')
                        metric_val = metric(y_val, pred_val, multi_class = 'ovr')

                          # Multiclassification - AUC
                        # [5] Predict
                        pred_train = model.predict_proba(X_train) # predict!
                        pred_val = model.predict_proba(X_val) # predict!

                        # [6] Compute metric
                        metric_train = metric(y_train, pred_train, multi_class = 'ovr')
                        metric_val = metric(y_val, pred_val, multi_class = 'ovr')
# Out:
#   File "<ipython-input-1-9bbae4f734fb>", line 3
#     pred_train = model.predict(X_train) # predict!
#     ^
# IndentationError: unexpected indent
